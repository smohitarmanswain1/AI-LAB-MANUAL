# %% [markdown]
# <a href="https://colab.research.google.com/github/smohitarmanswain1/AI-LAB-MANUAL/blob/main/EXPERIMENT_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence = input("Enter a sentence: ")
words = sorted(sentence.split())
sorted_sentence = " ".join(words)
print("Sorted sentence:", sorted_sentence)
# Out:
# Enter a sentence: Show an example of training a simple ML model
# Sorted sentence: ML Show a an example model of simple training

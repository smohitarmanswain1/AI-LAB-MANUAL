# %% [markdown]
# <a href="https://colab.research.google.com/github/smohitarmanswain1/AI-LAB-MANUAL/blob/main/EXPERIMENT_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
input_string = input("Enter a string: ")
no_punctuations = input_string.translate(str.maketrans("", "", string.punctuation))
print("String with no punctuations:", no_punctuations)
# Out:
# Enter a string: I AM PUNCTUATION
# String with no punctuations: I AM PUNCTUATION
